# %%
# %load_ext autoreload
# %autoreload 2

# %%
import utils
from collections import defaultdict
from concurrent.futures import ProcessPoolExecutor
from tqdm import tqdm
import os
import json

freq_langs = defaultdict(float)
num_cores = os.cpu_count() 
divide_batch = num_cores if num_cores is not None else 16

# %%
vocabulary = set()

config = utils.DocProcessingConfig(
    lemmatize=True,
    stopwords=True,
    lowercase=True,
    remove_punctuation=True,
)


with open(utils.CORPUS_PATH, "r") as f:
    raw_docs = json.load(f)
    # raw_docs = ijson.items(f, "item")
    for raw_doc in raw_docs:
        freq_langs[raw_doc['lang']] += 1

total_docs = int(sum(freq_langs.values()))
print("Total docs: ", total_docs)
print("\n## Raw frequencies")
for lang, freq in freq_langs.items():
    print(f'{lang}: {freq}')

print("\n## Normalized frequencies")
for lang, freq in freq_langs.items():
    freq_langs[lang] = freq * 100  / total_docs

for lang, freq in freq_langs.items():
    print(f'{lang}: {freq:.2f}%')
# Out:
# Total docs:  268022
#
# ## Raw frequencies
# en: 207363.0
# fr: 10676.0
# de: 10992.0
# es: 11019.0
# it: 11250.0
# ko: 7893.0
# ar: 8829.0
#
# ## Normalized frequencies
# en: 77.37%
# fr: 3.98%
# de: 4.10%
# es: 4.11%
# it: 4.20%
# ko: 2.94%
# ar: 3.29%

# %%
for lang in utils.Lang:
    vocab =  utils.load(f".cache/vocab_test_{lang.value}.pkl")
    print(lang.value)
    print(len(vocab))
    print()
# Out:
# de
# 604444
#
# fr
# 514244
#
# es
# 433406
#
# it
# 624928
#
# ar
# 175670
#
# en
# 2161857
#
# ko
# 350877

# %%
i = 0
en_vocab =  utils.load(f".cache/vocab_test_en.pkl")
for word in en_vocab:
    i+= 1
    if i < 2000:
        continue
    
    print(word)
    if i == 50:
        break
# Out:
# supramaximal
# trichobathra
# franchized
# fgth
# gojunen
# pondattithan
# daterie
# commencan
# rotenhof
# overlorded
# sebkhat
# onwisconsin
# kexts
# leano
# maadhu
# selenocosmia
# qiangbang
# douw
# unlife
# marzuoli
# hashimbekov
# nitidum
# seilbek
# simmerud
# puratam
# sdiy
# annoyd
# roslanbek
# bergum
# dissesion
# akkol
# lamphong
# kpeve
# nsacp
# kullager
# rastell
# maydaa
# pamenter
# tholekavu
# bugut
# zamas
# stigmatella
# pylas
# wpwx
# otthild
# nupeland
# manetphyan
# tonggok
# labonair
# fas
# raychikhlag
# gracilispora
# lepismatina
# acf
# nonispa
# suntherland
# cryptogamist
# falavigna
# holem
# colorwash
# pannacotta
# haier
# shaper
# necabettin
# redlink
# flugboot
# sagarbarh
# urtaca
# rekla
# boreviulisoma
# unjami
# zenturm
# metaocaml
# francescoi
# kayalar
# babineaux
# qet
# amblema
# qunqirat
# serraescuderio
# chandrabati
# greywater
# libental
# munras
# marupuru
# lahowitz
# flieder
# dalaraeus
# mcbath
# kawachiensis
# metcha
# argusia
# eremostachy
# kurtoxin
# nevse
# smogorzewo
# minutia
# twyhynde
# dtbcht
# dakhni
# paraso

# %%
weird = set(list(en_vocab)[:50])

config = utils.DocProcessingConfig(True, True, True, True, True, True)
with ProcessPoolExecutor(max_workers=num_cores) as executor:
    for batch in tqdm(utils.batch_load_documents(executor, divide_batch, config=config, lang=utils.Lang.ENGLISH)):
        for doc in batch:
            words = set(doc.getTokens())
            if any(word in words for word in weird):
                print(doc.getTokens())
# Out:
# 2it [00:37, 18.71s/it]
# ['japanese', 'television', 'series', 'metal', 'hero', 'series', 'franchise', 'sequel', 'juukou', 'fighter', 'take', 'place', 'year', 'precede', 'fighter', 'series', 'kabuto', 'air', 'action', 'footage', 'prop', 'beetleborgs', 'metallix', 'series', 'plot', 'year', 'destruction', 'jamahl', 'earth', 'return', 'peace', 'earth', 'academia', 'scientific', 'research', 'organization', 'takuya', 'kai', 'work', 'sage', 'guru', 'new', 'generation', 'insect', 'armor', 'event', 'threat', 'earth', 'threat', 'realize', 'cosmo', 'academia', 'exploration', 'submarine', 'come', 'fissure', 'ocean', 'floor', 'rise', 'huge', 'fly', 'fortress', 'ancient', 'tribe', 'melzard', 'clan', 'rest', 'millennium', 'seek', 'destroy', 'mankind', 'matriarch', 'mother', 'melzard', 'send', 'old', 'son', 'raija', 'dezzle', 'lead', 'attack', 'raija', 'elebamamoth', 'guru', 'infuse', 'neo', 'insect', 'armor', 'insect', 'power', 'create', 'command', 'voicer', 'link', 'human', 'armor', 'kengo', 'tachibana', 'run', 'ayukawa', 'select', 'wear', 'new', 'armor', 'ready', 'fighter', 'kuwagar', 'fighter', 'tentou', 'person', 'fighter', 'kabuto', 'choose', 'remain', 'command', 'voicer', 'fly', 'window', 'run', 'kengo', 'follow', 'meet', 'kouhei', 'toba', 'star', 'athlete', 'school', 'lose', 'badly', 'elebammoth', 'freeze', 'boy', 'sister', 'command', 'voicer', 'fly', 'hand', 'kengo', 'run', 'shock', 'high', 'school', 'student', 'fighter', 'kabuto', 'teach', 'transform', 'change', 'kabuto', 'attack', 'elebammoth', 'henchman', 'kabuto', 'kill', 'elebammoth', 'refuse', 'accept', 'defeat', 'mother', 'melzard', 'continue', 'attack', 'raija', 'dezzle', 'work', 'attack', 'fighter', 'character', 'new', 'generation', 'fighter', 'year', 'old', 'later', 'year', 'old', 'high', 'school', 'student', 'hijiri', 'sei', 'high', 'school', 'second', 'grade', 'grade', 'later', 'drag', 'fight', 'star', 'athlete', 'kouhei', 'courageous', 'fighter', 'impetuous', 'live', 'young', 'sister', 'yui', 'care', 'overprotect', 'kabuto', 'like', 'blue', 'beet', 'kouhei', 'don', 'armor', 'model', 'japanese', 'rhinoceros', 'beetle', 'kabuto', 'fighter', 'wield', 'astral', 'saber', 'gain', 'control', 'giant', 'robot', 'kabuterio', 'love', 'sophie', 'final', 'battle', 'leave', 'united', 'states', 'sophie', 'college', 'study', 'training', 'new', 'york', 'office', 'cosmo', 'academia', 'year', 'old', 'environment', 'investigator', 'originally', 'respect', 'kouhei', 'kouhei', 'choose', 'kabuto', 'instead', 'kouhei', 'young', 'eventually', 'friend', 'kuwagar', 'like', 'stag', 'kengo', 'don', 'armor', 'model', 'stag', 'beetle', 'end', 'series', 'kuwagar', 'able', 'wield', 'geist', 'axe', 'control', 'giant', 'robot', 'kuwaga', 'titan', 'descorpion', 'mother', 'melzard', 'evil', 'actually', 'evil', 'episode', 'reveal', 'father', 'diplomat', 'year', 'old', 'cyber', 'engineer', 'think', 'mechanic', 'ignore', 'natural', 'feeling', 'julio', 'teach', 'appreciate', 'nature', 'run', 'love', 'eat', 'skilled', 'play', 'shamisen', 'stringed', 'japanese', 'instrument', 'leave', 'parent', 'home', 'tentou', 'unlike', 'reddle', 'run', 'armor', 'model', 'ladybug', 'death', 'father', 'mother', 'move', 'united', 'states', 'study', 'hotel', 'management', 'new', 'fighter', 'individual', 'new', 'york', 'head', 'office', 'south', 'american', 'peking', 'paris', 'branch', 'cosmo', 'academia', 'variant', 'command', 'voicer', 'store', 'neo', 'insect', 'armor', 'activate', 'insert', 'respective', 'data', 'card', 'shout', 'consume', 'power', 'destroy', 'crystal', 'mother', 'melzard', 'ignite', 'detonator', 'inside', 'human', 'insect', 'commander', 'merge', 'geist', 'axe', 'finale', 'mac', 'new', 'york', 'office', 'master', 'boxing', 'aikido', 'choose', 'dragonfly', 'insect', 'medal', 'yanma', 'pose', 'exchange', 'student', 'kouhei', 'school', 'boy', 'rival', 'result', 'eventually', 'reveal', 'fighter', 'attack', 'crusher', 'make', 'enemy', 'mukadelinger', 'lose', 'kabuto', 'come', 'aid', 'give', 'tonbou', 'gun', 'mac', 'leave', 'america', 'tell', ...
# 3it [00:56, 18.93s/it]
# ['article', 'royal', 'italian', 'army', 'regio', 'esercito', 'participate', 'second', 'world', 'war', 'royal', 'italian', 'army', 'reform', 'exist', 'royal', 'army', 'start', 'unification', 'italy', 'risorgimento', 'formation', 'kingdom', 'italy', 'regno', 'end', 'dissolution', 'monarchy', 'royal', 'army', 'precede', 'individual', 'army', 'independent', 'italian', 'state', 'follow', 'italian', 'army', 'esercito', 'italiano', 'italian', 'republic', 'repubblica', 'italiana', 'organization', 'italian', 'army', 'world', 'war', 'royal', 'army', 'nominal', 'commander', 'chief', 'italian', 'royal', 'army', 'majesty', 'king', 'vittorio', 'emanuele', 'iii', 'commander', 'chief', 'italian', 'armed', 'force', 'vittorio', 'emanuele', 'command', 'royal', 'air', 'force', 'regia', 'aeronautica', 'royal', 'navy', 'regia', 'marina', 'reality', 'king', 'military', 'responsibility', 'assume', 'italian', 'prime', 'minister', 'benito', 'mussolini', 'mussolini', 'supreme', 'command', 'comando', 'supremo', 'supreme', 'command', 'feature', 'organic', 'staff', 'function', 'defense', 'ministry', 'high', 'command', 'defense', 'ministry', 'base', 'function', 'include', 'ministry', 'war', 'ministry', 'admiralty', 'ministry', 'air', 'high', 'command', 'base', 'geographic', 'region', 'include', 'army', 'group', 'west', 'army', 'group', 'albania', 'army', 'group', 'east', 'africa', 'army', 'group', 'aegean', 'army', 'group', 'libya', 'army', 'group', 'army', 'army', 'typically', 'compose', 'corp', 'separate', 'unit', 'directly', 'command', 'army', 'level', 'corp', 'typically', 'compose', 'division', 'separate', 'unit', 'directly', 'command', 'corps', 'level', 'division', 'basic', 'formation', 'italian
city', 'find', 'ann', 'darrow', 'promise', 'adventure', 'lifetime', 'crew', 'board', 'venture', 'set', 'ship', 'mate', 'jack', 'driscoll', 'fall', 'love', 'ann', 'denham', 'reveal', 'crew', 'destination', 'fact', 'skull', 'island', 'uncharted', 'territory', 'allude', 'mysterious', 'entity', 'name', 'kong', 'rumor', 'dwell', 'island', 'crew', 'arrive', 'anchor', 'offshore', 'encounter', 'native', 'village', 'separate', 'rest', 'island', 'enormous', 'stone', 'wall', 'large', 'wooden', 'gate', 'witness', 'group', 'native', 'prepare', 'sacrifice', 'young', 'woman', 'term', 'bride', 'kong', 'intruder', 'spot', 'native', 'chief', 'stop', 'ceremony', 'see', 'ann', 'offer', 'trade', 'tribal', 'woman', 'golden', 'woman', 'rebuff', 'return', 'venture', 'night', 'native', 'kidnap', 'ann', 'ship', 'gate', 'altar', 'offer', 'king', 'kong', 'enormous', 'gorilla', 'kong', 'carry', 'terrified', 'ann', 'away', 'denham', 'jack', 'volunteer', 'enter', 'jungle', 'hope', 'rescue', 'encounter', 'live', 'dinosaur', 'charge', 'stegosaurus', 'manage', 'kill', 'soon', 'crew', 'run', 'aggressive', 'brontosaurus', 'eventually', 'kong', 'leave', 'jack', 'denham', 'survivor', 'kong', 'slay', 'tyrannosaurus', 'rex', 'try', 'eat', 'ann', 'jack', 'continue', 'follow', 'denham', 'return', 'village', 'man', 'arrive', 'kong', 'mountain', 'lair', 'ann', 'menace', 'snake', 'like', 'elasmosaurus', 'kong', 'kill', 'kong', 'distract', 'kill', 'pteranodon', 'try', 'fly', 'away', 'ann', 'jack', 'reach', 'climb', 'vine', 'dangle', 'cliff', 'ledge', 'kong', 'notice', 'start', 'pull', 'drop', 'water', 'run', 'jungle', 'village', 'denham', 'englehorn', 'survive', 'crewman', 'wait', 'kong', 'follow', 'break', 'open', 'gate', 'relentlessly', 'rampage', 'village', 'onshore', 'denham', 'determined', 'bring', 'kong', 'alive', 'knock', 'unconscious', 'gas', 'bomb', 'shackle', 'chain', 'kong', 'take', 'new', 'york', 'city', 'present', 'broadway', 'theatre', 'audience', 'kong', 'eighth', 'wonder', 'world', 'ann', 'jack', 'bring', 'stage', 'join', 'surround', 'group', 'press', 'photographer', 'kong', 'believe', 'ensue', 'flash', 'photography', 'attack', 'break', 'loose', 'audience', 'flee', 'horror', 'ann', 'whisk', 'away', 'hotel', 'room', 'high', 'floor', 'kong', 'scale', 'building', 'soon', 'find', 'rampage', 'city', 'ann', 'scream', 'grip', 'wreck', 'crowded', 'elevated', 'train', 'eventually', 'climb', 'empire', 'state', 'building', 'attack', 'airplane', 'kong', 'destroy', 'finally', 'succumb', 'gunfire', 'gaze', 'ann', 'time', 'fall', 'death', 'jack', 'take', 'elevator', 'building', 'reunite', 'ann', 'denham', 'arrive', 'push', 'crowd', 'surround', 'kon ...
# 10it [03:17, 19.72s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 5
#       3 config = utils.DocProcessingConfig(True, True, True, True, True, True)
#       4 with ProcessPoolExecutor(max_workers=num_cores) as executor:
# ----> 5     for batch in tqdm(utils.batch_load_documents(executor, divide_batch, config=config, lang=utils.Lang.ENGLISH)):
#       6         for doc in batch:
#       7             words = set(doc.getTokens())
#
# File ~/miniconda3/envs/DIS-retrieval-text/lib/python3.11/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/MEGA/EPFL/Sem3/DistInfoSystems/Projects/DIS-text-retrieval-system/utils.py:326, in batch_load_documents(executor, divide_batch, config, path, lang)
#     324 if len(batch_raw) == LOAD_BATCH_SIZE:
#     325     if executor is not None:
# --> 326         yield list(executor.map(partial_create_doc, batch_raw, chunksize=LOAD_BATCH_SIZE // divide_batch))
#     327     else:
#     328         yield [partial_create_doc(raw_doc=d) for d in batch_raw]
#
# File ~/miniconda3/envs/DIS-retrieval-text/lib/python3.11/concurrent/futures/process.py:620, in _chain_from_iterable_of_lists(iterable)
#     614 def _chain_from_iterable_of_lists(iterable):
#     615     """
#     616     Specialized implementation of itertools.chain.from_iterable.
#     617     Each item in *iterable* should be a list.  This function is
#     618     careful not to keep references to yielded objects.
#     619     """
# --> 620     for element in iterable:
#     621         element.reverse()
#     622         while element:
#
# File ~/miniconda3/envs/DIS-retrieval-text/lib/python3.11/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/miniconda3/envs/DIS-retrieval-text/lib/python3.11/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~/miniconda3/envs/DIS-retrieval-text/lib/python3.11/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/miniconda3/envs/DIS-retrieval-text/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:

# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
db_path = 'tf_idf_and_idf.db'  # Replace with your actual database path
conn = sqlite3.connect(db_path)

# Get a cursor object
cursor = conn.cursor()

# Retrieve the names of all tables in the database
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# Print the names of all tables
print("Tables in the database:")
for table_name in tables:
    print(table_name[0])  # table_name is a tuple, get the first element

# Load each table into a DataFrame and show the first five rows of a specific column
specific_column_name = 'doc_id'  # Replace with your actual column name
for table_name in tables:
    if table_name[0].startswith('idf'):
        continue
    table_name = table_name[0]  # Extract the table name from the tuple
    df = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)  # Load table into DataFrame
    
    # Show the first five rows of the specific column if it exists
    if specific_column_name in df.columns:
        print(f"\nFirst five rows of '{specific_column_name}' in table '{table_name}':")
        print(df[specific_column_name].head())
    else:
        print(f"Column '{specific_column_name}' does not exist in table '{table_name}'.")

# Close the cursor and connection
cursor.close()
conn.close()
# Out:
# Tables in the database:
# tf_idf_de
# tf_idf_fr
# tf_idf_es
# tf_idf_it
# tf_idf_ar
# tf_idf_en
# tf_idf_ko
# idf
#
# First five rows of 'doc_id' in table 'tf_idf_de':
# Series([], Name: doc_id, dtype: object)
#
# First five rows of 'doc_id' in table 'tf_idf_fr':
# Series([], Name: doc_id, dtype: object)
#
# First five rows of 'doc_id' in table 'tf_idf_es':
# Series([], Name: doc_id, dtype: object)
#
# First five rows of 'doc_id' in table 'tf_idf_it':
# Series([], Name: doc_id, dtype: object)
#
# First five rows of 'doc_id' in table 'tf_idf_ar':
# Series([], Name: doc_id, dtype: object)
#
# First five rows of 'doc_id' in table 'tf_idf_en':
# 0    doc-en-11447
# 1     doc-en-9696
# 2     doc-en-4033
# 3    doc-en-10997
# 4     doc-en-3366
# Name: doc_id, dtype: object
#
# First five rows of 'doc_id' in table 'tf_idf_ko':
# Series([], Name: doc_id, dtype: object)
